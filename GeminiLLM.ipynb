# %% [markdown]
# <a href="https://colab.research.google.com/github/kazuya-ds/LLMChatBotwithCybersecurity/blob/main/GeminiLLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## References
# 1. https://medium.com/@nikhitha.joy.official/building-an-llm-powered-application-with-googles-gemini-api-a-step-by-step-guide-915a0e9d1088

# %%
pip -q install google-generativeai streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.0 MB/s eta 0:00:00

# %%
api_key = ""

# %%
# !pip install streamlit google-generativeai pyngrok

api_key = ""
import streamlit as st
import google.generativeai as genai

# %%
# Configure the Gemini API
import os

os.environ["GOOGLE_API_KEY"] = api_key

# genai.configure(api_key=api_key)

# %% [markdown]
# ## See Available Model

# %%
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# 2026-01-26 02:43:24.649 200 GET /v1beta/models?pageSize=50&%24alt=json%3Benum-encoding%3Dint (::1) 814.51ms
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# ...

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
import os

# Configure API key
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# Use a supported model
model = genai.GenerativeModel("gemini-2.5-flash")

st.title("LLM-Powered Text Generation with Gemini API")
st.write("Enter a prompt and let the AI generate some text for you.")

prompt = st.text_area("Enter your prompt here:")

if st.button("Generate Text"):
    if prompt:
        response = model.generate_content(prompt)
        st.subheader("Generated Text:")
        st.write(response.text)
    else:
        st.warning("Please enter a prompt.")
# Out:
# Overwriting app.py

# %%
# !pip -q install streamlit google-generativeai
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
# Out:
# ...
# Selecting previously unselected package cloudflared.
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2026.1.1) ...
# Setting up cloudflared (2026.1.1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !streamlit run app.py --server.port 8501 &>/content/logs.txt &

# %%
# !cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-01-26T02:45:09Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-01-26T02:45:09Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-01-26T02:45:14Z INF +--------------------------------------------------------------------------------------------+
# 2026-01-26T02:45:14Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...
